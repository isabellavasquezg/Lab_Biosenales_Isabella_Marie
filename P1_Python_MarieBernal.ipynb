# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellavasquezg/Lab_Biosenales_Isabella_Marie/blob/main/P1_Python_MarieBernal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Cree el siguiente par de vectores:
# a = [67.1,1, -0.3, 5.2, -6], b= [1, 3, 2.2, 5.1, 1]

# %%
import numpy as np
a = np.array([67.1,1, -0.3, 5.2, -6])
b = np.array([1, 3, 2.2, 5.1, 1])
print(a)
print(b)
# Out:
# [67.1  1.  -0.3  5.2 -6. ]
# [1.  3.  2.2 5.1 1. ]

# %% [markdown]
# b) Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar los dos
# vectores?
# c) Implemente la multiplicación punto a punto de a.b.
#
# Rta: Garantizar que ambos vectores tengan la misma longitud, dimensión y sus tipos de datos seán compatibles.

# %%
forma = a.shape == b.shape
Dato = a.dtype == b.dtype
Dim = a.ndim == b.ndim

if forma and Dato and Dim:
  print("Se puede multiplicar escalarmente")
  multEscalar = np.dot(a,b)
  print(multEscalar)
  multPunto = np.multiply(a,b)
  print(multPunto)
# Out:
# Se puede multiplicar escalarmente
# 89.96
# [67.1   3.   -0.66 26.52 -6.  ]

# %% [markdown]
# d) Construya la siguiente matriz:
# [ 2,  -1,  -3]
#
# [ 4,  -1.5,  -2.5]
#
# [7.3, -0.9, -0.2]

# %%
A = np.array([[2, -1, -3],[4, -1.5, -2.5],[7.3, -0.9, -0.2]])
print(A)
# Out:
# [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]

# %% [markdown]
# e) Obtenga su transpuesta AT.

# %%
AT = A.T
print(AT)
# Out:
# [[ 2.   4.   7.3]
#  [-1.  -1.5 -0.9]
#  [-3.  -2.5 -0.2]]

# %% [markdown]
# f) Consulte la función de los siguientes comandos de la librería numpy: *ones, round, ceil, floor*,
# implemente cada función para ejemplificar su uso.
# Ones: Crea un arreglo en el que todos sus elementos son unos.
# Round: Redondea un número hacia el entero más cercano. Se puede especificar la cantidad de decimales presentes en el resultado.
# Ceil: Redondea hacia el entero mayor a cada número o elemento de un arreglo.
# Floor: Redondea hacia el entero menor a cada número o elemento de un arreglo.

# %%
unos = np.ones(3)
print(unos)
redondeo = np.round(multEscalar,1)
print(redondeo)
Techo = np.ceil(multPunto)
print(Techo)
Piso = np.floor(multPunto)
print(Piso)
# Out:
# [1. 1. 1.]
# 90.0
# [68.  3. -0. 27. -6.]
# [67.  3. -1. 26. -6.]

# %% [markdown]
# g) Acceda al valor de la primera fila, tercera columna de la matriz A, imprímalo en consola.

# %%
Encontrarg = A[0,2]
print(Encontrarg)
# Out:
# -3.0

# %% [markdown]
# h) Obtenga la segunda fila de dicha matriz, imprímalo en consola.

# %%
Encontrarh = A[1]
print(Encontrarh)
# Out:
# [ 4.  -1.5 -2.5]

# %% [markdown]
# i) Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz A e
# imprímalo en consola.

# %%
dimension = A.shape
D1 = A.ndim
print(dimension)
print(D1)
# Out:
# (3, 3)
# 2

# %% [markdown]
# j) Construya la función  𝑦[𝑛] = sin (𝜋 ∗ 0.18𝑛) en el intervalo 0 <= n <= 80.

# %%
import matplotlib.pyplot as plt
n = np.arange(0,81)
y1 = np.sin(np.pi * 0.18 * n)

# %% [markdown]
# k) Construya otra senoidal 𝑦2[𝑛] = cos(2𝜋 ∗ 0.03𝑛)

# %%
y2 = np.cos(np.pi * 2* 0.03 * n)

# %% [markdown]
# l) Genere una tercera señal que sea la suma de estas dos señales, es decir
# *s*[𝑛] = y[n] +𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛] = y[n].𝑦2[𝑛].

# %%
s = y1 + y2
t = y1*y2

# %% [markdown]
# m) Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada
# señal. Asigne título a cada eje.

# %%
figura, ejes = plt.subplots()
ejes.plot(n, y1, label='y1 = sin(π * 0.18 * n)', color='red', marker='x')
ejes.plot(n, y2, label='y2 = cos(π * 2 * 0.03 * n)', color='blue', marker='o')
ejes.set_title('Gráfica de  y1[n] vs y2[n]')
ejes.set_xlabel('n')
ejes.set_ylabel('y[n]')
ejes.legend()
ejes.grid(True)

# %% [markdown]
# n) Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada
# señal. Asigne título a cada eje.

# %%
figura, ejes = plt.subplots()
ejes.plot(n, s, label='s[n]', color='pink', marker='<')
ejes.plot(n, t, label='t[n]', color='orange', marker='*')
ejes.set_title('Gráfica de  s[n] vs t[n]')
ejes.set_xlabel('n')
ejes.set_ylabel('y[n]')
ejes.legend()
ejes.grid(True)

# %% [markdown]
# ¡RETO!
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una
# serie con la nota mínima, la máxima, media y la desviación típica.

# %%
import pandas as pd
dic_notas = {"Marie": 3.8, "Laura": 4.8, "Dairon": 5.0, "Anny": 4.6, "Paula": 4.0, "Paulina": 5.0, "Andrea": 4.5}
def cursobio(dic_notas):
  notas = list(dic_notas.values())
  min = np.min(notas)
  max = np.max(notas)
  media = np.mean(notas)
  sigma = np.std(notas)
  result_serie = pd.Series([min, max, media, sigma], index=['nota mínima', 'nota máxima', 'media', 'desviación típica'])
  return result_serie
print (result_serie)
# Out:
# nota mínima          3.800000
# nota máxima          5.000000
# media                4.528571
# desviación típica    0.436592
# dtype: float64
